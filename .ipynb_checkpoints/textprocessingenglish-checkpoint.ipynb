# %%
import nltk #import library nltk
from nltk.tokenize import word_tokenize #import word_tokenize for tokenizing text into words 
from nltk.tokenize import sent_tokenize #import sent_tokenize for tokenizing paragraph into sentences
from nltk.stem.porter import PorterStemmer #import Porter Stemmer Algorithm 
from nltk.stem import WordNetLemmatizer #import WordNet lemmatizer 
from nltk.corpus import stopwords #import stopwords
from nltk.tokenize import RegexpTokenizer
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory #import Indonesian Stemmer
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from collections import Counter
import re #import regular expression

# %%
file = open ('english.txt','r')
n = file.read()

def sentence_tokenization(s): 
    sentences_list = sent_tokenize(s)
    
   
    return sentences_list 

text_data = n
sentence_tokenization(text_data)
# Out:
# ['Lyft launches a scooter service.',
#  'Uber is close behind\n\nLyft launched a fleet of electric scooters in Denver on Thursday, stepping squarely into the rapidly growing scooter-sharing market so far dominated by the likes of Bird and Lime.',
#  "Uber is expected to deploy its own scooters in rival Bird's hometown of Santa Monica, California within a few weeks, according to a company spokesperson.",
#  'Although the two companies are synonymous with ridesharing, they see tremendous potential in electric scooters and bicycles.',
#  'The devices, which are popular with commuters, help reduce congestion and complement public transit.',
#  'That could help offset mounting criticism -- backed by several studies -- that show ridesharing leads to more traffic as people shift from mass transit to cars.',
#  '"Scooters are a way to make daily trips more fun and encourage multimodal commuting," Caroline Samponaro, who leads bike and scooter policy at Lyft, told CNN Money.',
#  'Eager to further facilitate the switch to scooters, Lyft will soon offer anyone riding its scooters a discount if they start or end their ride near public transit.',
#  "Scooters can be found through Lyft's app, and prices mirror industry standards of $1 to unlock a scooter and 15 cents a minute.",
#  "The company is also adding a feature in its app to let commuters know when they're near public transit stops.",
#  "Uber, which acquired bikesharing startup Jump in April, has seen riders in San Francisco shifting from cars to electric bikes, suggesting the ridesharing giants must expand beyond cars if they don't want to see upstarts siphon away business.",
#  'Samponaro said Lyft has received a ton of demand from cities interested in scooters.',
#  'Lyft will launch scooters in Santa Monica Sept. 17.',
#  "It's interested in expanding to other cities, but will take its cue on when to launch from city governments, according to Samponaro.",
#  "Lyft's approach differs from that of Bird and Lime, which launched in Denver and many other cities earlier this year without municipal approval.",
#  'The approach rankled some cities, but helped the companies grow quickly and win over customers.',
#  'Bird and Lime have raised money from investors at a faster pace than Uber and Lyft did.',
#  'Such aggressive tactics are a throwback to the early days of ridesharing, and in fact, Bird is led by CEO Travis VanderZanden, a veteran of both Uber and Lyft.',
#  'Uber and Lyft are being more measured in dealing with local governments today.',
#  "Lyft's fleet uses scooters much like those everyone else uses, but the company is offering some novel features.",
#  'Riders can pay an added fee of 15 cents a minute to reserve a scooter through the app, for example.',
#  'And the company will rely upon full-time employees to charge and maintain its fleet rather than using contract employees.',
#  "It expects this will lead to better care of its scooters, so users can feel more confident they aren't about to ride on a broken or dangerous scooter.",
#  '"We think it\'s important that as the bike and scooter industry grows that there are good job opportunities paralleling that," Samponaro said.']

# %%
def casefolding(s):
    new_str = s.lower()
    
    return new_str

low = casefolding(text_data)
print(low)
# Out:
# lyft launches a scooter service. uber is close behind
#
# lyft launched a fleet of electric scooters in denver on thursday, stepping squarely into the rapidly growing scooter-sharing market so far dominated by the likes of bird and lime.
# uber is expected to deploy its own scooters in rival bird's hometown of santa monica, california within a few weeks, according to a company spokesperson.
#
# although the two companies are synonymous with ridesharing, they see tremendous potential in electric scooters and bicycles. the devices, which are popular with commuters, help reduce congestion and complement public transit. that could help offset mounting criticism -- backed by several studies -- that show ridesharing leads to more traffic as people shift from mass transit to cars.
#
# "scooters are a way to make daily trips more fun and encourage multimodal commuting," caroline samponaro, who leads bike and scooter policy at lyft, told cnn money.
#
# eager to further facilitate the switch to scooters, lyft will soon offer anyone riding its scooters a discount if they start or end their ride near public transit. scooters can be found through lyft's app, and prices mirror industry standards of $1 to unlock a scooter and 15 cents a minute. the company is also adding a feature in its app to let commuters know when they're near public transit stops.
#
# uber, which acquired bikesharing startup jump in april, has seen riders in san francisco shifting from cars to electric bikes, suggesting the ridesharing giants must expand beyond cars if they don't want to see upstarts siphon away business.
#
# samponaro said lyft has received a ton of demand from cities interested in scooters. lyft will launch scooters in santa monica sept. 17. it's interested in expanding to other cities, but will take its cue on when to launch from city governments, according to samponaro.
#
# lyft's approach differs from that of bird and lime, which launched in denver and many other cities earlier this year without municipal approval. the approach rankled some cities, but helped the companies grow quickly and win over customers. bird and lime have raised money from investors at a faster pace than uber and lyft did.
#
# such aggressive tactics are a throwback to the early days of ridesharing, and in fact, bird is led by ceo travis vanderzanden, a veteran of both uber and lyft. uber and lyft are being more measured in dealing with local governments today.
# lyft's fleet uses scooters much like those everyone else uses, but the company is offering some novel features. riders can pay an added fee of 15 cents a minute to reserve a scooter through the app, for example. and the company will rely upon full-time employees to charge and maintain its fleet rather than using contract employees. it expects this will lead to better care of its scooters, so users can feel more confident they aren't about to ride on a broken or dangerous scooter.
#
# "we think it's important that as the bike and scooter industry grows that there are good job opportunities paralleling that," samponaro said.

# %%
def removePunc(str):
    new_string =  re.sub(r"[\W]", " ", str)
    return new_string
punc = removePunc(low)
print(punc)
# Out:
# lyft launches a scooter service  uber is close behind  lyft launched a fleet of electric scooters in denver on thursday  stepping squarely into the rapidly growing scooter sharing market so far dominated by the likes of bird and lime  uber is expected to deploy its own scooters in rival bird s hometown of santa monica  california within a few weeks  according to a company spokesperson   although the two companies are synonymous with ridesharing  they see tremendous potential in electric scooters and bicycles  the devices  which are popular with commuters  help reduce congestion and complement public transit  that could help offset mounting criticism    backed by several studies    that show ridesharing leads to more traffic as people shift from mass transit to cars    scooters are a way to make daily trips more fun and encourage multimodal commuting   caroline samponaro  who leads bike and scooter policy at lyft  told cnn money   eager to further facilitate the switch to scooters  lyft will soon offer anyone riding its scooters a discount if they start or end their ride near public transit  scooters can be found through lyft s app  and prices mirror industry standards of  1 to unlock a scooter and 15 cents a minute  the company is also adding a feature in its app to let commuters know when they re near public transit stops   uber  which acquired bikesharing startup jump in april  has seen riders in san francisco shifting from cars to electric bikes  suggesting the ridesharing giants must expand beyond cars if they don t want to see upstarts siphon away business   samponaro said lyft has received a ton of demand from cities interested in scooters  lyft will launch scooters in santa monica sept  17  it s interested in expanding to other cities  but will take its cue on when to launch from city governments  according to samponaro   lyft s approach differs from that of bird and lime  which launched in denver and many other cities earlier this year without municipal approval  the approach rankled some cities  but helped the companies grow quickly and win over customers  bird and lime have raised money from investors at a faster pace than uber and lyft did   such aggressive tactics are a throwback to the early days of ridesharing  and in fact  bird is led by ceo travis vanderzanden  a veteran of both uber and lyft  uber and lyft are being more measured in dealing with local governments today  lyft s fleet uses scooters much like those everyone else uses  but the company is offering some novel features  riders can pay an added fee of 15 cents a minute to reserve a scooter through the app  for example  and the company will rely upon full time employees to charge and maintain its fleet rather than using contract employees  it expects this will lead to better care of its scooters  so users can feel more confident they aren t about to ride on a broken or dangerous scooter    we think it s important that as the bike and scooter industry grows that there are good job opportunities paralleling that   samponaro said

# %%
import nltk 
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Sofia
# [nltk_data]     Dewi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

example_sent = punc

stop_words = set(stopwords.words('english')) 

word_tokens = word_tokenize(example_sent) 

filtered_sentence = [w for w in word_tokens if not w in stop_words]  
filtered_sentence = [] 

for w in word_tokens: 
    if w not in stop_words: 
        filtered_sentence.append(w) 

print(word_tokens) 
print(filtered_sentence)
# Out:
# ['lyft', 'launches', 'a', 'scooter', 'service', 'uber', 'is', 'close', 'behind', 'lyft', 'launched', 'a', 'fleet', 'of', 'electric', 'scooters', 'in', 'denver', 'on', 'thursday', 'stepping', 'squarely', 'into', 'the', 'rapidly', 'growing', 'scooter', 'sharing', 'market', 'so', 'far', 'dominated', 'by', 'the', 'likes', 'of', 'bird', 'and', 'lime', 'uber', 'is', 'expected', 'to', 'deploy', 'its', 'own', 'scooters', 'in', 'rival', 'bird', 's', 'hometown', 'of', 'santa', 'monica', 'california', 'within', 'a', 'few', 'weeks', 'according', 'to', 'a', 'company', 'spokesperson', 'although', 'the', 'two', 'companies', 'are', 'synonymous', 'with', 'ridesharing', 'they', 'see', 'tremendous', 'potential', 'in', 'electric', 'scooters', 'and', 'bicycles', 'the', 'devices', 'which', 'are', 'popular', 'with', 'commuters', 'help', 'reduce', 'congestion', 'and', 'complement', 'public', 'transit', 'that', 'could', 'help', 'offset', 'mounting', 'criticism', 'backed', 'by', 'several', 'studies', 'that', 'show', 'ridesharing', 'leads', 'to', 'more', 'traffic', 'as', 'people', 'shift', 'from', 'mass', 'transit', 'to', 'cars', 'scooters', 'are', 'a', 'way', 'to', 'make', 'daily', 'trips', 'more', 'fun', 'and', 'encourage', 'multimodal', 'commuting', 'caroline', 'samponaro', 'who', 'leads', 'bike', 'and', 'scooter', 'policy', 'at', 'lyft', 'told', 'cnn', 'money', 'eager', 'to', 'further', 'facilitate', 'the', 'switch', 'to', 'scooters', 'lyft', 'will', 'soon', 'offer', 'anyone', 'riding', 'its', 'scooters', 'a', 'discount', 'if', 'they', 'start', 'or', 'end', 'their', 'ride', 'near', 'public', 'transit', 'scooters', 'can', 'be', 'found', 'through', 'lyft', 's', 'app', 'and', 'prices', 'mirror', 'industry', 'standards', 'of', '1', 'to', 'unlock', 'a', 'scooter', 'and', '15', 'cents', 'a', 'minute', 'the', 'company', 'is', 'also', 'adding', 'a', 'feature', 'in', 'its', 'app', 'to', 'let', 'commuters', 'know', 'when', 'they', 're', 'near', 'public', 'transit', 'stops', 'uber', 'which', 'acquired', 'bikesharing', 'startup', 'jump', 'in', 'april', 'has', 'seen', 'riders', 'in', 'san', 'francisco', 'shifting', 'from', 'cars', 'to', 'electric', 'bikes', 'suggesting', 'the', 'ridesharing', 'giants', 'must', 'expand', 'beyond', 'cars', 'if', 'they', 'don', 't', 'want', 'to', 'see', 'upstarts', 'siphon', 'away', 'business', 'samponaro', 'said', 'lyft', 'has', 'received', 'a', 'ton', 'of', 'demand', 'from', 'cities', 'interested', 'in', 'scooters', 'lyft', 'will', 'launch', 'scooters', 'in', 'santa', 'monica', 'sept', '17', 'it', 's', 'interested', 'in', 'expanding', 'to', 'other', 'cities', 'but', 'will', 'take', 'its', 'cue', 'on', 'when', 'to', 'launch', 'from', 'city', 'governments', 'according', 'to', 'samponaro', 'lyft', 's', 'approach', 'differs', 'from', 'that', 'of', 'bird', 'and', 'lime', 'which', 'launched', 'in', 'denver', 'and', 'many', 'other', 'cities', 'earlier', 'this', 'year', 'without', 'municipal', 'approval', 'the', 'approach', 'rankled', 'some', 'cities', 'but', 'helped', 'the', 'companies', 'grow', 'quickly', 'and', 'win', 'over', 'customers', 'bird', 'and', 'lime', 'have', 'raised', 'money', 'from', 'investors', 'at', 'a', 'faster', 'pace', 'than', 'uber', 'and', 'lyft', 'did', 'such', 'aggressive', 'tactics', 'are', 'a', 'throwback', 'to', 'the', 'early', 'days', 'of', 'ridesharing', 'and', 'in', 'fact', 'bird', 'is', 'led', 'by', 'ceo', 'travis', 'vanderzanden', 'a', 'veteran', 'of', 'both', 'uber', 'and', 'lyft', 'uber', 'and', 'lyft', 'are', 'being', 'more', 'measured', 'in', 'dealing', 'with', 'local', 'governments', 'today', 'lyft', 's', 'fleet', 'uses', 'scooters', 'much', 'like', 'those', 'everyone', 'else', 'uses', 'but', 'the', 'company', 'is', 'offering', 'some', 'novel', 'features', 'riders', 'can', 'pay', 'an', 'added', 'fee', 'of', '15', 'cents', 'a', 'minute', 'to', 'reserve', 'a', 'scooter', 'through', 'the', 'app', 'for', 'example', 'and', 'the', 'company', 'will', 'rely', 'upon', 'full', 'time', 'employees', 'to', 'charg ...
# ['lyft', 'launches', 'scooter', 'service', 'uber', 'close', 'behind', 'lyft', 'launched', 'fleet', 'electric', 'scooters', 'denver', 'thursday', 'stepping', 'squarely', 'rapidly', 'growing', 'scooter', 'sharing', 'market', 'far', 'dominated', 'likes', 'bird', 'lime', 'uber', 'expected', 'deploy', 'scooters', 'rival', 'bird', 'hometown', 'santa', 'monica', 'california', 'within', 'weeks', 'according', 'company', 'spokesperson', 'although', 'two', 'companies', 'synonymous', 'ridesharing', 'see', 'tremendous', 'potential', 'electric', 'scooters', 'bicycles', 'devices', 'popular', 'commuters', 'help', 'reduce', 'congestion', 'complement', 'public', 'transit', 'could', 'help', 'offset', 'mounting', 'criticism', 'backed', 'several', 'studies', 'show', 'ridesharing', 'leads', 'traffic', 'people', 'shift', 'mass', 'transit', 'cars', 'scooters', 'way', 'make', 'daily', 'trips', 'fun', 'encourage', 'multimodal', 'commuting', 'caroline', 'samponaro', 'leads', 'bike', 'scooter', 'policy', 'lyft', 'told', 'cnn', 'money', 'eager', 'facilitate', 'switch', 'scooters', 'lyft', 'soon', 'offer', 'anyone', 'riding', 'scooters', 'discount', 'start', 'end', 'ride', 'near', 'public', 'transit', 'scooters', 'found', 'lyft', 'app', 'prices', 'mirror', 'industry', 'standards', '1', 'unlock', 'scooter', '15', 'cents', 'minute', 'company', 'also', 'adding', 'feature', 'app', 'let', 'commuters', 'know', 'near', 'public', 'transit', 'stops', 'uber', 'acquired', 'bikesharing', 'startup', 'jump', 'april', 'seen', 'riders', 'san', 'francisco', 'shifting', 'cars', 'electric', 'bikes', 'suggesting', 'ridesharing', 'giants', 'must', 'expand', 'beyond', 'cars', 'want', 'see', 'upstarts', 'siphon', 'away', 'business', 'samponaro', 'said', 'lyft', 'received', 'ton', 'demand', 'cities', 'interested', 'scooters', 'lyft', 'launch', 'scooters', 'santa', 'monica', 'sept', '17', 'interested', 'expanding', 'cities', 'take', 'cue', 'launch', 'city', 'governments', 'according', 'samponaro', 'lyft', 'approach', 'differs', 'bird', 'lime', 'launched', 'denver', 'many', 'cities', 'earlier', 'year', 'without', 'municipal', 'approval', 'approach', 'rankled', 'cities', 'helped', 'companies', 'grow', 'quickly', 'win', 'customers', 'bird', 'lime', 'raised', 'money', 'investors', 'faster', 'pace', 'uber', 'lyft', 'aggressive', 'tactics', 'throwback', 'early', 'days', 'ridesharing', 'fact', 'bird', 'led', 'ceo', 'travis', 'vanderzanden', 'veteran', 'uber', 'lyft', 'uber', 'lyft', 'measured', 'dealing', 'local', 'governments', 'today', 'lyft', 'fleet', 'uses', 'scooters', 'much', 'like', 'everyone', 'else', 'uses', 'company', 'offering', 'novel', 'features', 'riders', 'pay', 'added', 'fee', '15', 'cents', 'minute', 'reserve', 'scooter', 'app', 'example', 'company', 'rely', 'upon', 'full', 'time', 'employees', 'charge', 'maintain', 'fleet', 'rather', 'using', 'contract', 'employees', 'expects', 'lead', 'better', 'care', 'scooters', 'users', 'feel', 'confident', 'ride', 'broken', 'dangerous', 'scooter', 'think', 'important', 'bike', 'scooter', 'industry', 'grows', 'good', 'job', 'opportunities', 'paralleling', 'samponaro', 'said']

# %%
str1 = ' '.join(filtered_sentence)
print(str1)
# Out:
# lyft launches scooter service uber close behind lyft launched fleet electric scooters denver thursday stepping squarely rapidly growing scooter sharing market far dominated likes bird lime uber expected deploy scooters rival bird hometown santa monica california within weeks according company spokesperson although two companies synonymous ridesharing see tremendous potential electric scooters bicycles devices popular commuters help reduce congestion complement public transit could help offset mounting criticism backed several studies show ridesharing leads traffic people shift mass transit cars scooters way make daily trips fun encourage multimodal commuting caroline samponaro leads bike scooter policy lyft told cnn money eager facilitate switch scooters lyft soon offer anyone riding scooters discount start end ride near public transit scooters found lyft app prices mirror industry standards 1 unlock scooter 15 cents minute company also adding feature app let commuters know near public transit stops uber acquired bikesharing startup jump april seen riders san francisco shifting cars electric bikes suggesting ridesharing giants must expand beyond cars want see upstarts siphon away business samponaro said lyft received ton demand cities interested scooters lyft launch scooters santa monica sept 17 interested expanding cities take cue launch city governments according samponaro lyft approach differs bird lime launched denver many cities earlier year without municipal approval approach rankled cities helped companies grow quickly win customers bird lime raised money investors faster pace uber lyft aggressive tactics throwback early days ridesharing fact bird led ceo travis vanderzanden veteran uber lyft uber lyft measured dealing local governments today lyft fleet uses scooters much like everyone else uses company offering novel features riders pay added fee 15 cents minute reserve scooter app example company rely upon full time employees charge maintain fleet rather using contract employees expects lead better care scooters users feel confident ride broken dangerous scooter think important bike scooter industry grows good job opportunities paralleling samponaro said

# %%
#Lemmatization
wordnet_lemmatizer = WordNetLemmatizer()

nltk_tokens = nltk.word_tokenize(str1)

for w in nltk_tokens:
       print ("Actual: %s  Lemma: %s"  % (w,wordnet_lemmatizer.lemmatize(w)))
# Out:
# Actual: lyft  Lemma: lyft
# Actual: launches  Lemma: launch
# Actual: scooter  Lemma: scooter
# Actual: service  Lemma: service
# Actual: uber  Lemma: uber
# Actual: close  Lemma: close
# Actual: behind  Lemma: behind
# Actual: lyft  Lemma: lyft
# Actual: launched  Lemma: launched
# Actual: fleet  Lemma: fleet
# Actual: electric  Lemma: electric
# Actual: scooters  Lemma: scooter
# Actual: denver  Lemma: denver
# Actual: thursday  Lemma: thursday
# Actual: stepping  Lemma: stepping
# Actual: squarely  Lemma: squarely
# Actual: rapidly  Lemma: rapidly
# Actual: growing  Lemma: growing
# Actual: scooter  Lemma: scooter
# Actual: sharing  Lemma: sharing
# Actual: market  Lemma: market
# Actual: far  Lemma: far
# Actual: dominated  Lemma: dominated
# Actual: likes  Lemma: like
# Actual: bird  Lemma: bird
# Actual: lime  Lemma: lime
# Actual: uber  Lemma: uber
# Actual: expected  Lemma: expected
# Actual: deploy  Lemma: deploy
# Actual: scooters  Lemma: scooter
# Actual: rival  Lemma: rival
# Actual: bird  Lemma: bird
# Actual: hometown  Lemma: hometown
# Actual: santa  Lemma: santa
# Actual: monica  Lemma: monica
# Actual: california  Lemma: california
# Actual: within  Lemma: within
# Actual: weeks  Lemma: week
# Actual: according  Lemma: according
# Actual: company  Lemma: company
# Actual: spokesperson  Lemma: spokesperson
# Actual: although  Lemma: although
# Actual: two  Lemma: two
# Actual: companies  Lemma: company
# Actual: synonymous  Lemma: synonymous
# Actual: ridesharing  Lemma: ridesharing
# Actual: see  Lemma: see
# Actual: tremendous  Lemma: tremendous
# Actual: potential  Lemma: potential
# Actual: electric  Lemma: electric
# Actual: scooters  Lemma: scooter
# Actual: bicycles  Lemma: bicycle
# Actual: devices  Lemma: device
# Actual: popular  Lemma: popular
# Actual: commuters  Lemma: commuter
# Actual: help  Lemma: help
# Actual: reduce  Lemma: reduce
# Actual: congestion  Lemma: congestion
# Actual: complement  Lemma: complement
# Actual: public  Lemma: public
# Actual: transit  Lemma: transit
# Actual: could  Lemma: could
# Actual: help  Lemma: help
# Actual: offset  Lemma: offset
# Actual: mounting  Lemma: mounting
# Actual: criticism  Lemma: criticism
# Actual: backed  Lemma: backed
# Actual: several  Lemma: several
# Actual: studies  Lemma: study
# Actual: show  Lemma: show
# Actual: ridesharing  Lemma: ridesharing
# Actual: leads  Lemma: lead
# Actual: traffic  Lemma: traffic
# Actual: people  Lemma: people
# Actual: shift  Lemma: shift
# Actual: mass  Lemma: mass
# Actual: transit  Lemma: transit
# Actual: cars  Lemma: car
# Actual: scooters  Lemma: scooter
# Actual: way  Lemma: way
# Actual: make  Lemma: make
# Actual: daily  Lemma: daily
# Actual: trips  Lemma: trip
# Actual: fun  Lemma: fun
# Actual: encourage  Lemma: encourage
# Actual: multimodal  Lemma: multimodal
# Actual: commuting  Lemma: commuting
# Actual: caroline  Lemma: caroline
# Actual: samponaro  Lemma: samponaro
# Actual: leads  Lemma: lead
# Actual: bike  Lemma: bike
# Actual: scooter  Lemma: scooter
# Actual: policy  Lemma: policy
# Actual: lyft  Lemma: lyft
# Actual: told  Lemma: told
# Actual: cnn  Lemma: cnn
# Actual: money  Lemma: money
# Actual: eager  Lemma: eager
# Actual: facilitate  Lemma: facilitate
# Actual: switch  Lemma: switch
# Actual: scooters  Lemma: scooter
# Actual: lyft  Lemma: lyft
# Actual: soon  Lemma: soon
# Actual: offer  Lemma: offer
# Actual: anyone  Lemma: anyone
# Actual: riding  Lemma: riding
# Actual: scooters  Lemma: scooter
# Actual: discount  Lemma: discount
# Actual: start  Lemma: start
# Actual: end  Lemma: end
# Actual: ride  Lemma: ride
# Actual: near  Lemma: near
# Actual: public  Lemma: public
# Actual: transit  Lemma: transit
# Actual: scooters  Lemma: scooter
# Actual: found  Lemma: found
# Actual: lyft  Lemma: lyft
# Actual: app  Lemma: app
# Actual: prices  Lemma: price
# Actual: mirror  Lemma: mirror
# Actual: industry  Lemma: industry
# Actual: standards  Lemma: standard
# Actual: 1  Lemma: 1
# Actual: unlock  Lemma: unlock
# Actual: scooter  Lemma: scooter
# Actual: 15  Lemma: 15
# Actual: cents  Lemma: cent
# Actual: minute  Lemma: minute
# Actual: company  Lemma: company
# Actual: also  Lemma: also
# Actual: adding  Lemma: adding
# Actual: feature  Lemma: feature
# Actual: app  Lemma: app
# Actual: let  Lemma: let
# Actual: commuters  Lemma: commuter
# Actual: know  Lemma: know
# Actual: near  Lemma: near
# Actual: public  Lemma: public
# Actual: transit  Lemma: transit
# Actual: stops  Lemma: stop
# Actual: uber  Lemma: uber
# Actual: acquired  Lemma: acquired
# Actual: bikesharing  Lemma: bikesharing
# Actual: startup  Lemma: startup
# Actual: jump  Lemma: jump
# Actual: april  Lemma: april
# Actual: seen  Lemma: seen
# Actual: riders  Lemma: rider
# Actual: san  Lemma: san
# Actual: francisco  Lemma: francisco
# Actual: shifting  Lemma: shifting
# Actual: cars  Lemma: car
# Actual: electric  Lemma: electric
# Actual: bikes  Lemma: bike
# Actual: suggesting  Lemma: suggesting
# Actual: ridesharing  Lemma: ridesharing
# Actual: giants  Lemma: giant
# Actual: must  Lemma: must
# Actual: expand  Lemma: expand
# Actual: beyond  Lemma: beyond
# Actual: cars  Lemma: car
# Actual: want  Lemma: want
# Actual: see  Lemma: see
# Actual: upstarts  Lemma: upstart
# Actual: siphon  Lemma: siphon
# Actual: away  Lemma: away
# Actual: business  Lemma: business
# Actual: samponaro  Lemma: samponaro
# Actual: said  Lemma: said
# Actual: lyft  Lemma: lyft
# Actual: received  Lemma: received
# Actual: ton  Lemma: ton
# Actual: demand  Lemma: demand
# Actual: cities  Lemma: city
# Actual: interested  Lemma: interested
# Actual: scooters  Lemma: scooter
# Actual: lyft  Lemma: lyft
# Actual: launch  Lemma: launch
# Actual: scooters  Lemma: scooter
# Actual: santa  Lemma: santa
# Actual: monica  Lemma: monica
# Actual: sept  Lemma: sept
# Actual: 17  Lemma: 17
# Actual: interested  Lemma: interested
# Actual: expanding  Lemma: expanding
# Actual: cities  Lemma: city
# Actual: take  Lemma: take
# Actual: cue  Lemma: cue
# Actual: launch  Lemma: launch
# Actual: city  Lemma: city
# Actual: governments  Lemma: government
# Actual: according  Lemma: according
# Actual: samponaro  Lemma: samponaro
# Actual: lyft  Lemma: lyft
# Actual: approach  Lemma: approach
# Actual: differs  Lemma: differs
# Actual: bird  Lemma: bird
# Actual: lime  Lemma: lime
# Actual: launched  Lemma: launched
# Actual: denver  Lemma: denver
# Actual: many  Lemma: many
# Actual: cities  Lemma: city
# Actual: earlier  Lemma: earlier
# Actual: year  Lemma: year
# Actual: without  Lemma: without
# Actual: municipal  Lemma: municipal
# Actual: approval  Lemma: approval
# Actual: approach  Lemma: approach
# Actual: rankled  Lemma: rankled
# Actual: cities  Lemma: city
# Actual: helped  Lemma: helped
# Actual: companies  Lemma: company
# Actual: grow  Lemma: grow
# Actual: quickly  Lemma: quickly
# Actual: win  Lemma: win
# Actual: customers  Lemma: customer
# Actual: bird  Lemma: bird
# Actual: lime  Lemma: lime
# Actual: raised  Lemma: raised
# Actual: money  Lemma: money
# Actual: investors  Lemma: investor
# Actual: faster  Lemma: faster
# Actual: pace  Lemma: pace
# Actual: uber  Lemma: uber
# Actual: lyft  Lemma: lyft
# Actual: aggressive  Lemma: aggressive
# Actual: tactics  Lemma: tactic
# Actual: throwback  Lemma: throwback
# Actual: early  Lemma: early
# Actual: days  Lemma: day
# Actual: ridesharing  Lemma: ridesharing
# Actual: fact  Lemma: fact
# Actual: bird  Lemma: bird
# Actual: led  Lemma: led
# Actual: ceo  Lemma: ceo
# Actual: travis  Lemma: travis
# Actual: vanderzanden  Lemma: vanderzanden
# Actual: veteran  Lemma: veteran
# Actual: uber  Lemma: uber
# Actual: lyft  Lemma: lyft
# Actual: uber  Lemma: uber
# Actual: lyft  Lemma: lyft
# Actual: measured  Lemma: measured
# Actual: dealing  Lemma: dealing
# Actual: local  Lemma: local
# Actual: governments  Lemma: government
# Actual: today  Lemma: today
# Actual: lyft  Lemma: lyft
# Actual: fleet  Lemma: fleet
# Actual: uses  Lemma: us
# Actual: scooters  Lemma: scooter
# Actual: much  Lemma: much
# Actual: like  Lemma: like
# Actual: everyone  Lemma: everyone
# Actual: else  Lemma: else
# Actual: uses  Lemma: us
# Actual: company  Lemma: company
# Actual: offering  Lemma: offering
# Actual: novel  Lemma: novel
# Actual: features  Lemma: feature
# Actual: riders  Lemma: rider
# Actual: pay  Lemma: pay
# Actual: added  Lemma: added
# Actual: fee  Lemma: fee
# Actual: 15  Lemma: 15
# Actual: cents  Lemma: cent
# Actual: minute  Lemma: minute
# Actual: reserve  Lemma: reserve
# Actual: scooter  Lemma: scooter
# Actual: app  Lemma: app
# Actual: example  Lemma: example
# Actual: company  Lemma: company
# Actual: rely  Lemma: rely
# Actual: upon  Lemma: upon
# Actual: full  Lemma: full
# Actual: time  Lemma: time
# Actual: employees  Lemma: employee
# Actual: charge  Lemma: charge
# Actual: maintain  Lemma: maintain
# Actual: fleet  Lemma: fleet
# Actual: rather  Lemma: rather
# Actual: using  Lemma: using
# Actual: contract  Lemma: contract
# Actual: employees  Lemma: employee
# Actual: expects  Lemma: expects
# Actual: lead  Lemma: lead
# Actual: better  Lemma: better
# Actual: care  Lemma: care
# Actual: scooters  Lemma: scooter
# Actual: users  Lemma: user
# Actual: feel  Lemma: feel
# Actual: confident  Lemma: confident
# Actual: ride  Lemma: ride
# Actual: broken  Lemma: broken
# Actual: dangerous  Lemma: dangerous
# Actual: scooter  Lemma: scooter
# Actual: think  Lemma: think
# Actual: important  Lemma: important
# Actual: bike  Lemma: bike
# Actual: scooter  Lemma: scooter
# Actual: industry  Lemma: industry
# Actual: grows  Lemma: grows
# Actual: good  Lemma: good
# Actual: job  Lemma: job
# Actual: opportunities  Lemma: opportunity
# Actual: paralleling  Lemma: paralleling
# Actual: samponaro  Lemma: samponaro
# Actual: said  Lemma: said

# %%
#Stemming English
def stemmingEnglish(str):
    porter_stemmer = PorterStemmer()
    words = word_tokenize(str)
    result = list()
    for word in words:
        result.append(porter_stemmer.stem(word))
        
    return ' '.join(result)

stem = stemmingEnglish(str1)
print(stem)
# Out:
# lyft launch scooter servic uber close behind lyft launch fleet electr scooter denver thursday step squar rapidli grow scooter share market far domin like bird lime uber expect deploy scooter rival bird hometown santa monica california within week accord compani spokesperson although two compani synonym rideshar see tremend potenti electr scooter bicycl devic popular commut help reduc congest complement public transit could help offset mount critic back sever studi show rideshar lead traffic peopl shift mass transit car scooter way make daili trip fun encourag multimod commut carolin samponaro lead bike scooter polici lyft told cnn money eager facilit switch scooter lyft soon offer anyon ride scooter discount start end ride near public transit scooter found lyft app price mirror industri standard 1 unlock scooter 15 cent minut compani also ad featur app let commut know near public transit stop uber acquir bikeshar startup jump april seen rider san francisco shift car electr bike suggest rideshar giant must expand beyond car want see upstart siphon away busi samponaro said lyft receiv ton demand citi interest scooter lyft launch scooter santa monica sept 17 interest expand citi take cue launch citi govern accord samponaro lyft approach differ bird lime launch denver mani citi earlier year without municip approv approach rankl citi help compani grow quickli win custom bird lime rais money investor faster pace uber lyft aggress tactic throwback earli day rideshar fact bird led ceo travi vanderzanden veteran uber lyft uber lyft measur deal local govern today lyft fleet use scooter much like everyon els use compani offer novel featur rider pay ad fee 15 cent minut reserv scooter app exampl compani reli upon full time employe charg maintain fleet rather use contract employe expect lead better care scooter user feel confid ride broken danger scooter think import bike scooter industri grow good job opportun parallel samponaro said

# %%
def postag(str):
    tok_sentence = nltk.word_tokenize(str)
    tagged_sentence = nltk.pos_tag(tok_sentence)
    return tagged_sentence

pt = postag(stem)
print(pt)
# Out:
# [('lyft', 'NN'), ('launch', 'NN'), ('scooter', 'NN'), ('servic', 'JJ'), ('uber', 'NNP'), ('close', 'NN'), ('behind', 'IN'), ('lyft', 'JJ'), ('launch', 'JJ'), ('fleet', 'NN'), ('electr', 'JJ'), ('scooter', 'NN'), ('denver', 'NN'), ('thursday', 'JJ'), ('step', 'NN'), ('squar', 'VBD'), ('rapidli', 'JJ'), ('grow', 'NN'), ('scooter', 'NN'), ('share', 'NN'), ('market', 'NN'), ('far', 'RB'), ('domin', 'VBZ'), ('like', 'IN'), ('bird', 'NN'), ('lime', 'JJ'), ('uber', 'JJ'), ('expect', 'VBP'), ('deploy', 'JJ'), ('scooter', 'NN'), ('rival', 'JJ'), ('bird', 'NN'), ('hometown', 'JJ'), ('santa', 'NN'), ('monica', 'NN'), ('california', 'NN'), ('within', 'IN'), ('week', 'NN'), ('accord', 'NN'), ('compani', 'NN'), ('spokesperson', 'NN'), ('although', 'IN'), ('two', 'CD'), ('compani', 'NNS'), ('synonym', 'JJ'), ('rideshar', 'NNS'), ('see', 'VBP'), ('tremend', 'JJ'), ('potenti', 'NN'), ('electr', 'NN'), ('scooter', 'NN'), ('bicycl', 'NN'), ('devic', 'NN'), ('popular', 'JJ'), ('commut', 'NN'), ('help', 'NN'), ('reduc', 'VB'), ('congest', 'JJ'), ('complement', 'NN'), ('public', 'JJ'), ('transit', 'NN'), ('could', 'MD'), ('help', 'VB'), ('offset', 'VB'), ('mount', 'NN'), ('critic', 'JJ'), ('back', 'RB'), ('sever', 'NN'), ('studi', 'NN'), ('show', 'NN'), ('rideshar', 'JJ'), ('lead', 'NN'), ('traffic', 'NN'), ('peopl', 'JJ'), ('shift', 'NN'), ('mass', 'NN'), ('transit', 'NN'), ('car', 'NN'), ('scooter', 'NN'), ('way', 'NN'), ('make', 'VBP'), ('daili', 'NN'), ('trip', 'NN'), ('fun', 'NN'), ('encourag', 'VBP'), ('multimod', 'NN'), ('commut', 'NN'), ('carolin', 'NN'), ('samponaro', 'JJ'), ('lead', 'NN'), ('bike', 'NN'), ('scooter', 'NN'), ('polici', 'NN'), ('lyft', 'NN'), ('told', 'VBD'), ('cnn', 'JJ'), ('money', 'NN'), ('eager', 'NN'), ('facilit', 'VBP'), ('switch', 'NN'), ('scooter', 'NN'), ('lyft', 'NN'), ('soon', 'RB'), ('offer', 'VBP'), ('anyon', 'JJ'), ('ride', 'NN'), ('scooter', 'NN'), ('discount', 'NN'), ('start', 'JJ'), ('end', 'NN'), ('ride', 'NN'), ('near', 'IN'), ('public', 'JJ'), ('transit', 'NN'), ('scooter', 'NN'), ('found', 'VBD'), ('lyft', 'RB'), ('app', 'JJ'), ('price', 'NN'), ('mirror', 'NN'), ('industri', 'JJ'), ('standard', 'NN'), ('1', 'CD'), ('unlock', 'NN'), ('scooter', 'NN'), ('15', 'CD'), ('cent', 'NN'), ('minut', 'NN'), ('compani', 'NN'), ('also', 'RB'), ('ad', 'NN'), ('featur', 'NN'), ('app', 'JJ'), ('let', 'NN'), ('commut', 'NN'), ('know', 'VB'), ('near', 'IN'), ('public', 'JJ'), ('transit', 'NN'), ('stop', 'VB'), ('uber', 'NNP'), ('acquir', 'JJ'), ('bikeshar', 'NN'), ('startup', 'NN'), ('jump', 'NN'), ('april', 'NN'), ('seen', 'VBN'), ('rider', 'VB'), ('san', 'JJ'), ('francisco', 'NN'), ('shift', 'NN'), ('car', 'NN'), ('electr', 'VBP'), ('bike', 'NN'), ('suggest', 'VBP'), ('rideshar', 'NN'), ('giant', 'NN'), ('must', 'MD'), ('expand', 'VB'), ('beyond', 'IN'), ('car', 'NN'), ('want', 'VBP'), ('see', 'VB'), ('upstart', 'JJ'), ('siphon', 'VB'), ('away', 'RP'), ('busi', 'JJ'), ('samponaro', 'NN'), ('said', 'VBD'), ('lyft', 'JJ'), ('receiv', 'NN'), ('ton', 'NN'), ('demand', 'NN'), ('citi', 'JJ'), ('interest', 'NN'), ('scooter', 'NN'), ('lyft', 'VBD'), ('launch', 'JJ'), ('scooter', 'NN'), ('santa', 'NN'), ('monica', 'NN'), ('sept', 'VBD'), ('17', 'CD'), ('interest', 'NN'), ('expand', 'NN'), ('citi', 'NNS'), ('take', 'VBP'), ('cue', 'NN'), ('launch', 'NN'), ('citi', 'NN'), ('govern', 'JJ'), ('accord', 'NN'), ('samponaro', 'NN'), ('lyft', 'NN'), ('approach', 'NN'), ('differ', 'VBP'), ('bird', 'NN'), ('lime', 'NN'), ('launch', 'NN'), ('denver', 'RB'), ('mani', 'VBD'), ('citi', 'NNS'), ('earlier', 'RBR'), ('year', 'NN'), ('without', 'IN'), ('municip', 'NN'), ('approv', 'NN'), ('approach', 'NN'), ('rankl', 'NN'), ('citi', 'NN'), ('help', 'NN'), ('compani', 'VB'), ('grow', 'VB'), ('quickli', 'JJ'), ('win', 'NN'), ('custom', 'NN'), ('bird', 'NN'), ('lime', 'NN'), ('rais', 'VB'), ('money', 'NN'), ('investor', 'NN'), ('faster', 'RBR'), ('pace', 'NN'), ('uber', 'NNP'), ('lyft', 'NN'), ('aggress', 'NN'), ('tactic', 'JJ'), ('throwback', 'NN' ...

# %%
count = Counter(filtered_sentence)
print(count)
# Out:
# Counter({'lyft': 12, 'scooters': 11, 'scooter': 7, 'uber': 6, 'bird': 5, 'company': 4, 'ridesharing': 4, 'transit': 4, 'samponaro': 4, 'cities': 4, 'fleet': 3, 'electric': 3, 'lime': 3, 'public': 3, 'cars': 3, 'app': 3, 'launched': 2, 'denver': 2, 'santa': 2, 'monica': 2, 'according': 2, 'companies': 2, 'see': 2, 'commuters': 2, 'help': 2, 'leads': 2, 'bike': 2, 'money': 2, 'ride': 2, 'near': 2, 'industry': 2, '15': 2, 'cents': 2, 'minute': 2, 'riders': 2, 'said': 2, 'interested': 2, 'launch': 2, 'governments': 2, 'approach': 2, 'uses': 2, 'employees': 2, 'launches': 1, 'service': 1, 'close': 1, 'behind': 1, 'thursday': 1, 'stepping': 1, 'squarely': 1, 'rapidly': 1, 'growing': 1, 'sharing': 1, 'market': 1, 'far': 1, 'dominated': 1, 'likes': 1, 'expected': 1, 'deploy': 1, 'rival': 1, 'hometown': 1, 'california': 1, 'within': 1, 'weeks': 1, 'spokesperson': 1, 'although': 1, 'two': 1, 'synonymous': 1, 'tremendous': 1, 'potential': 1, 'bicycles': 1, 'devices': 1, 'popular': 1, 'reduce': 1, 'congestion': 1, 'complement': 1, 'could': 1, 'offset': 1, 'mounting': 1, 'criticism': 1, 'backed': 1, 'several': 1, 'studies': 1, 'show': 1, 'traffic': 1, 'people': 1, 'shift': 1, 'mass': 1, 'way': 1, 'make': 1, 'daily': 1, 'trips': 1, 'fun': 1, 'encourage': 1, 'multimodal': 1, 'commuting': 1, 'caroline': 1, 'policy': 1, 'told': 1, 'cnn': 1, 'eager': 1, 'facilitate': 1, 'switch': 1, 'soon': 1, 'offer': 1, 'anyone': 1, 'riding': 1, 'discount': 1, 'start': 1, 'end': 1, 'found': 1, 'prices': 1, 'mirror': 1, 'standards': 1, '1': 1, 'unlock': 1, 'also': 1, 'adding': 1, 'feature': 1, 'let': 1, 'know': 1, 'stops': 1, 'acquired': 1, 'bikesharing': 1, 'startup': 1, 'jump': 1, 'april': 1, 'seen': 1, 'san': 1, 'francisco': 1, 'shifting': 1, 'bikes': 1, 'suggesting': 1, 'giants': 1, 'must': 1, 'expand': 1, 'beyond': 1, 'want': 1, 'upstarts': 1, 'siphon': 1, 'away': 1, 'business': 1, 'received': 1, 'ton': 1, 'demand': 1, 'sept': 1, '17': 1, 'expanding': 1, 'take': 1, 'cue': 1, 'city': 1, 'differs': 1, 'many': 1, 'earlier': 1, 'year': 1, 'without': 1, 'municipal': 1, 'approval': 1, 'rankled': 1, 'helped': 1, 'grow': 1, 'quickly': 1, 'win': 1, 'customers': 1, 'raised': 1, 'investors': 1, 'faster': 1, 'pace': 1, 'aggressive': 1, 'tactics': 1, 'throwback': 1, 'early': 1, 'days': 1, 'fact': 1, 'led': 1, 'ceo': 1, 'travis': 1, 'vanderzanden': 1, 'veteran': 1, 'measured': 1, 'dealing': 1, 'local': 1, 'today': 1, 'much': 1, 'like': 1, 'everyone': 1, 'else': 1, 'offering': 1, 'novel': 1, 'features': 1, 'pay': 1, 'added': 1, 'fee': 1, 'reserve': 1, 'example': 1, 'rely': 1, 'upon': 1, 'full': 1, 'time': 1, 'charge': 1, 'maintain': 1, 'rather': 1, 'using': 1, 'contract': 1, 'expects': 1, 'lead': 1, 'better': 1, 'care': 1, 'users': 1, 'feel': 1, 'confident': 1, 'broken': 1, 'dangerous': 1, 'think': 1, 'important': 1, 'grows': 1, 'good': 1, 'job': 1, 'opportunities': 1, 'paralleling': 1})
